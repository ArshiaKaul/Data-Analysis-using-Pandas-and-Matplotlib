# %%
# Import pandas library

# %%
import pandas as pd

# %% [markdown]
# # Dataset 1

# %%
set = pd.read_csv(r"./CSV_Files/ebola_data_db_format.csv")

# %%
set.head()
# Out:
#                                            Indicator Country        Date  \
# 0  Cumulative number of confirmed, probable and s...  Guinea  2015-03-10
# 1         Cumulative number of confirmed Ebola cases  Guinea  2015-03-10
# 2          Cumulative number of probable Ebola cases  Guinea  2015-03-10
# 3         Cumulative number of suspected Ebola cases  Guinea  2015-03-10
# 4  Cumulative number of confirmed, probable and s...  Guinea  2015-03-10
#
#     value
# 0  3285.0
# 1  2871.0
# 2   392.0
# 3    22.0
# 4  2170.0

# %%
set.dtypes
# Out:
# Indicator     object
# Country       object
# Date          object
# value        float64
# dtype: object

# %%
# guinea has been mentioned twice
set[set.Country.isin(["Guinea"])].head()
# Out:
#                                            Indicator Country        Date  \
# 0  Cumulative number of confirmed, probable and s...  Guinea  2015-03-10
# 1         Cumulative number of confirmed Ebola cases  Guinea  2015-03-10
# 2          Cumulative number of probable Ebola cases  Guinea  2015-03-10
# 3         Cumulative number of suspected Ebola cases  Guinea  2015-03-10
# 4  Cumulative number of confirmed, probable and s...  Guinea  2015-03-10
#
#     value
# 0  3285.0
# 1  2871.0
# 2   392.0
# 3    22.0
# 4  2170.0

# %%
set[set.Country.isin(["Guinea 2"])]["Date"].unique().tolist()
# Out:
# ['2016-03-23']

# %%
# Guinea has data corresponding to 2014-2015
set[set.Country.isin(["Guinea"])]["Date"].unique()
# Out:
# array(['2015-03-10', '2015-03-06', '2015-03-05', '2015-03-04',
#        '2015-03-02', '2015-02-27', '2015-02-26', '2015-02-25',
#        '2015-02-23', '2015-02-20', '2015-02-19', '2015-02-18',
#        '2015-02-17', '2015-02-16', '2015-02-13', '2015-02-12',
#        '2015-02-11', '2015-02-10', '2015-02-06', '2015-02-05',
#        '2015-02-04', '2015-02-03', '2015-02-02', '2015-01-30',
#        '2015-01-29', '2015-01-28', '2015-01-27', '2015-01-26',
#        '2015-01-23', '2015-01-22', '2015-01-21', '2015-01-20',
#        '2015-01-19', '2015-01-16', '2015-01-15', '2015-01-14',
#        '2015-01-13', '2015-01-12', '2015-01-09', '2015-01-08',
#        '2015-01-07', '2015-01-06', '2015-01-05', '2015-01-02',
#        '2014-12-31', '2014-12-30', '2014-12-29', '2014-12-26',
#        '2014-12-24', '2014-12-23', '2014-12-22', '2014-12-17',
#        '2014-12-15', '2014-12-10', '2014-12-03', '2014-12-01',
#        '2014-11-26', '2014-11-21', '2014-11-19', '2014-11-14',
# ...

# %%
set[(set["Country"]=="Guinea 2") & (set["Date"]=='2016-03-23')]
# Out:
# Indicator    10
# Country      10
# Date         10
# value        10
# dtype: int64

# %%
set[set.Country.isin(["Guinea 2"])]["Date"].unique().tolist()
# Out:
# ['2016-03-23']

# %%
set.groupby("Indicator").agg("count").loc[:,["Country"]]
# Out:
#                                                     Country
# Indicator
# Case fatality rate (CFR) of confirmed Ebola cases        19
# Case fatality rate (CFR) of confirmed, probable...       19
# Case fatality rate (CFR) of probable Ebola cases         18
# Case fatality rate (CFR) of suspected Ebola cases        18
# Cumulative number of confirmed Ebola cases             2484
# Cumulative number of confirmed Ebola deaths            1648
# Cumulative number of confirmed, probable and su...     2477
# Cumulative number of confirmed, probable and su...     2485
# Cumulative number of probable Ebola cases              2436
# Cumulative number of probable Ebola deaths             1526
# Cumulative number of suspected Ebola cases             2366
# Cumulative number of suspected Ebola deaths            1308
# Number of confirmed Ebola cases in the last 21 ...      190
# Number of confirmed Ebola cases in the last 7 days        6
# ...

# %% [markdown]
# # Dataset 2: Only Guinea (Similar sets are available for Liberia and Seirra Leone)

# %%
import pandas as pd

# %%
#import numpy as np

# %%
guinea = pd.read_csv(r"./CSV_Files/Guinea2016-05-11.csv")

# %%
guinea.head()
# Out:
#   Country Age group Gender    Location    Ebola measure Case definition  \
# 0  Guinea       NaN    NaN  FORECARIAH  Number of cases       Confirmed
# 1  Guinea       NaN    NaN       BEYLA  Number of cases        Probable
# 2  Guinea       NaN    NaN   GUECKEDOU  Number of cases        Probable
# 3  Guinea       NaN    NaN      KINDIA  Number of cases       Confirmed
# 4  Guinea       NaN    NaN      TOUGUE  Number of cases       Confirmed
#
#   Ebola data source                            Epi week Indicator type  \
# 0  Situation report    25 to 31 January 2016 (2016-W04)            New
# 1  Situation report   08 to 14 February 2016 (2016-W06)            New
# 2  Situation report  22 to 28 September 2014 (2014-W39)            New
# 3  Situation report  08 to 14 September 2014 (2014-W37)            New
# 4  Situation report    19 to 25 January 2015 (2015-W04)            New
#
#            Data package ID Data as of Outbreak identifier Display Value  \
# ...

# %%
guinea.dtypes
# Out:
# Country                 object
# Age group               object
# Gender                  object
# Location                object
# Ebola measure           object
# Case definition         object
# Ebola data source       object
# Epi week                object
# Indicator type          object
# Data package ID         object
# Data as of              object
# Outbreak identifier     object
# Display Value           object
# Numeric                float64
# Low                    float64
# High                   float64
# Comments                object
# dtype: object

# %%
guinea.loc[guinea.Comments.notnull(), "Comments"].count()
# Out:
# 24

# %%
# get the unique values in each of the columns
for col in guinea.columns:  
    print (col)
    print (guinea[col].unique())
    print ("\n")
# Out:
# Country
# ['Guinea']
#
#
# Age group
# [nan '45+' 'All ages (total)' '15-44' '0-14']
#
#
# Gender
# [nan 'Both sexes' 'Male' 'Female']
#
#
# Location
# ['FORECARIAH' 'BEYLA' 'GUECKEDOU' 'KINDIA' 'TOUGUE' 'LELOUMA' 'DALABA'
#  'DUBREKA' 'MACENTA' "N'ZEREKORE" 'COYAH' 'KANKAN' 'LABE' 'SIGUIRI' 'FRIA'
#  'DINGUIRAYE' 'LOLA' 'YOMOU' 'FARANAH' 'TELIMELE' 'GAOUAL' 'CONAKRY'
#  'KISSIDOUGOU' 'KEROUANE' 'KOUBIA' 'MAMOU' 'BOKE' 'PITA' 'KOUROUSSA'
#  'KOUNDARA' 'MALI' 'BOFFA' nan 'DABOLA']
#
#
# Ebola measure
# ['Number of cases' 'Number of deaths']
#
#
# Case definition
# ['Confirmed' 'Probable' 'Total' 'Suspected']
#
#
# Ebola data source
# ['Situation report' 'Patient database' nan]
#
#
# Epi week
# ['25 to 31 January 2016 (2016-W04)' '08 to 14 February 2016 (2016-W06)'
#  '22 to 28 September 2014 (2014-W39)' '08 to 14 September 2014 (2014-W37)'
#  '19 to 25 January 2015 (2015-W04)'
#  '28 September to 04 October 2015 (2015-W40)'
#  '14 to 20 December 2015 (2015-W51)'
# ...

# %%
# number of unique values in each column
for col in guinea.columns:  
    print (col + ": {}".format(guinea[col].unique().size))
    #print ("\n")
# Out:
# Country: 1
# Age group: 5
# Gender: 4
# Location: 34
# Ebola measure: 2
# Case definition: 4
# Ebola data source: 3
# Epi week: 124
# Indicator type: 3
# Data package ID: 1
# Data as of: 3
# Outbreak identifier: 3
# Display Value: 102
# Numeric: 99
# Low: 1
# High: 1
# Comments: 6
